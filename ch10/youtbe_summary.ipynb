# %% [markdown]
# # Youtube 요약

# %% [markdown]
# ## 필요 라이브러리 설치

# %%
# %pip install youtube-search
# Out:
# Requirement already satisfied: youtube-search in c:\programdata\anaconda3\envs\llm\lib\site-packages (2.1.2)
# Requirement already satisfied: requests in c:\programdata\anaconda3\envs\llm\lib\site-packages (from youtube-search) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\envs\llm\lib\site-packages (from requests->youtube-search) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\llm\lib\site-packages (from requests->youtube-search) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\envs\llm\lib\site-packages (from requests->youtube-search) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\llm\lib\site-packages (from requests->youtube-search) (2025.8.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 키워드 검색 및 결과

# %%
from youtube_search import YoutubeSearch

videos = YoutubeSearch("미국 대선", max_results=5).to_dict()
videos
# Out:
# [{'id': '4A3P9Tgm8wc',
#   'thumbnails': ['https://i.ytimg.com/vi/4A3P9Tgm8wc/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLBiKa6FlGtJbPpVcHb4Nkfj_G7yqQ',
#    'https://i.ytimg.com/vi/4A3P9Tgm8wc/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLA9dp_amuxkebdEB0E_Yg87rC4ZQA'],
#   'title': '[2020 미국 대선] 표 적게 받고도 대통령 된다? 복잡한 선거제도 6분 총정리 ❙ Won Less, but Elected Anyways? / 비디오머그',
#   'long_desc': None,
#   'channel': '비디오머그 - VIDEOMUG',
#   'duration': '5:50',
#   'views': '조회수 518,254회',
#   'publish_time': '5년 전',
#   'url_suffix': '/watch?v=4A3P9Tgm8wc&pp=ygUN66-46rWtIOuMgOyEoA%3D%3D'},
#  {'id': 'yUrKS8KldPk',
#   'thumbnails': ['https://i.ytimg.com/vi/yUrKS8KldPk/hqdefault.jpg?sqp=-oaymwEjCOADEI4CSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLCXV5GBAOBgjsk55XCwjUmlZCl-gw'],
#   'title': '[Explained] 미국 대선, 어렵지 않아요!  / SBS',
#   'long_desc': None,
#   'channel': 'SBS 뉴스',
#   'duration': '5:12',
#   'views': '조회수 142,848회',
#   'publish_time': '9년 전',
#   'url_suffix': '/watch?v=yUrKS8KldPk&pp=ygUN66-46rWtIOuMgOyEoA%3D%3D'},
#  {'id': 'rY5_-jEUJYw',
#   'thumbnails': ['https://i.ytimg.com/vi/rY5_-jEUJYw/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLBYYnU7eCb5PSpQCM3gDhOf1bt73g',
#    'https://i.ytimg.com/vi/rY5_-jEUJYw/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLDcZRS4dfbO_u3K-XKj5S99g25Wiw'],
#   'title': '[LIVE] 2024 미국 대선 결과 분석 정리',
#   'long_desc': None,
#   'channel': '김지윤의 지식Play',
#   'duration': '1:25:34',
#   'views': '조회수 398,620회',
#   'publish_time': '스트리밍 시간: 1년 전',
#   'url_suffix': '/watch?v=rY5_-jEUJYw&pp=ygUN66-46rWtIOuMgOyEoA%3D%3D'},
#  {'id': 'GGPiVs7GC-M',
#   'thumbnails': ['https://i.ytimg.com/vi/GGPiVs7GC-M/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLC-pM-eV4g21mUoXBO9auwPSIKThg',
#    'https://i.ytimg.com/vi/GGPiVs7GC-M/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLCB4e7S4R4Rz3R2QIuCQrZ2EUpp7A'],
#   'title': '[데이터M] 2024 미국 대선 개표 상황 (2024.11.06/뉴스특보/MBC)',
#   'long_desc': None,
#   'channel': 'MBCNEWS',
#   'duration': '2:57',
#   'views': '조회수 19,459회',
#   'publish_time': '1년 전',
#   'url_suffix': '/watch?v=GGPiVs7GC-M&pp=ygUN66-46rWtIOuMgOyEoA%3D%3D'},
#  {'id': 'LKHzlzh7HBs',
#   'thumbnails': ['https://i.ytimg.com/vi/LKHzlzh7HBs/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLDeGBYbq18px6ES3r95qgC-rERrMg',
#    'https://i.ytimg.com/vi/LKHzlzh7HBs/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLB4q1lp3LRY4-ASZp-U0YU5Dqq9dw'],
#   'title': "🇺🇸[미국대선특집] 대통령 선거 제도 '선거인단'의 유래와 역사",
#   'long_desc': None,
#   'channel': '조승연의 탐구생활',
#   'duration': '15:33',
#   'views': '조회수 1,257,972회',
#   'publish_time': '5년 전',
#   'url_suffix': '/watch?v=LKHzlzh7HBs&pp=ygUN66-46rWtIOuMgOyEoA%3D%3D'}]

# %% [markdown]
# ## 검색 결과 활용해 영상 주소 만들기

# %%
video_url = 'http://youtube.com' + videos[3]['url_suffix']
video_url
# Out:
# 'http://youtube.com/watch?v=GGPiVs7GC-M&pp=ygUN66-46rWtIOuMgOyEoA%3D%3D'

# %% [markdown]
# ## 자막 라이브러리 설치

# %%
# %pip install youtube_transcript_api
# Out:
# Requirement already satisfied: youtube_transcript_api in c:\programdata\anaconda3\envs\llm\lib\site-packages (1.2.3)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in c:\programdata\anaconda3\envs\llm\lib\site-packages (from youtube_transcript_api) (0.7.1)
# Requirement already satisfied: requests in c:\programdata\anaconda3\envs\llm\lib\site-packages (from youtube_transcript_api) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\envs\llm\lib\site-packages (from requests->youtube_transcript_api) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\llm\lib\site-packages (from requests->youtube_transcript_api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\envs\llm\lib\site-packages (from requests->youtube_transcript_api) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\llm\lib\site-packages (from requests->youtube_transcript_api) (2025.8.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## YoutubeLoader를 통해 자막 가져오기

# %%
from langchain_community.document_loaders import YoutubeLoader

loader = YoutubeLoader.from_youtube_url(
    video_url, 
    language=['ko', 'en'] # 자막 언어
)

loader.load()
# Out:
# ---------------------------------------------------------------------------
# IpBlocked                                 Traceback (most recent call last)
# Cell In[6], line 8
#       1 from langchain_community.document_loaders import YoutubeLoader
#       3 loader = YoutubeLoader.from_youtube_url(
#       4     video_url,
#       5     language=['ko', 'en'] # 자막 언어
#       6 )
# ----> 8 loader.load()
#
# File c:\ProgramData\anaconda3\envs\llm\Lib\site-packages\langchain_community\document_loaders\youtube.py:274, in YoutubeLoader.load(self)
#     272 if self.translation is not None:
#     273     transcript = transcript.translate(self.translation)
# --> 274 transcript_object = transcript.fetch()
#     275 if isinstance(transcript_object, FetchedTranscript):
#     276     transcript_pieces = [
#     277         {
#     278             "text": snippet.text,
#    (...)    282         for snippet in transcript_object.snippets
#     283     ]
#
# File c:\ProgramData\anaconda3\envs\llm\Lib\site-packages\youtube_transcript_api\_transcripts.py:139, in Transcript.fetch(self, preserve_formatting)
#     136     raise PoTokenRequired(self.video_id)
#     137 response = self._http_client.get(self._url)
#     138 snippets = _TranscriptParser(preserve_formatting=preserve_formatting).parse(
# --> 139     _raise_http_errors(response, self.video_id).text,
#     140 )
#     141 return FetchedTranscript(
#     142     snippets=snippets,
#     143     video_id=self.video_id,
#    (...)    146     is_generated=self.is_generated,
#     147 )
#
# File c:\ProgramData\anaconda3\envs\llm\Lib\site-packages\youtube_transcript_api\_transcripts.py:96, in _raise_http_errors(response, video_id)
#      94 try:
#      95     if response.status_code == 429:
# ---> 96         raise IpBlocked(video_id)
#      97     response.raise_for_status()
#      98     return response
#
# IpBlocked:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=GGPiVs7GC-M! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!

# %%
for v in videos:
    # url_suffix를 이용해 video_url 생성
    v['video_url'] = 'https://youtube.com' + v['url_suffix']
    
    # YoutubeLoader를 이용해 비디오 로드
    loader = YoutubeLoader.from_youtube_url(
        v['video_url'],
        language=['ko', 'en']
    )

    v['content'] = loader.load()

videos
# Out:
# ---------------------------------------------------------------------------
# IpBlocked                                 Traceback (most recent call last)
# Cell In[7], line 11
#       5     # YoutubeLoader를 이용해 비디오 로드
#       6     loader = YoutubeLoader.from_youtube_url(
#       7         v['video_url'],
#       8         language=['ko', 'en']
#       9     )
# ---> 11     v['content'] = loader.load()
#      13 videos
#
# File c:\ProgramData\anaconda3\envs\llm\Lib\site-packages\langchain_community\document_loaders\youtube.py:274, in YoutubeLoader.load(self)
#     272 if self.translation is not None:
#     273     transcript = transcript.translate(self.translation)
# --> 274 transcript_object = transcript.fetch()
#     275 if isinstance(transcript_object, FetchedTranscript):
#     276     transcript_pieces = [
#     277         {
#     278             "text": snippet.text,
#    (...)    282         for snippet in transcript_object.snippets
#     283     ]
#
# File c:\ProgramData\anaconda3\envs\llm\Lib\site-packages\youtube_transcript_api\_transcripts.py:139, in Transcript.fetch(self, preserve_formatting)
#     136     raise PoTokenRequired(self.video_id)
#     137 response = self._http_client.get(self._url)
#     138 snippets = _TranscriptParser(preserve_formatting=preserve_formatting).parse(
# --> 139     _raise_http_errors(response, self.video_id).text,
#     140 )
#     141 return FetchedTranscript(
#     142     snippets=snippets,
#     143     video_id=self.video_id,
#    (...)    146     is_generated=self.is_generated,
#     147 )
#
# File c:\ProgramData\anaconda3\envs\llm\Lib\site-packages\youtube_transcript_api\_transcripts.py:96, in _raise_http_errors(response, video_id)
#      94 try:
#      95     if response.status_code == 429:
# ---> 96         raise IpBlocked(video_id)
#      97     response.raise_for_status()
#      98     return response
#
# IpBlocked:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=4A3P9Tgm8wc! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!

# %%
print('총 영상 수:', len(videos))
# 영상 길이가 60분 이하인 영상만 남김
videos = [v for v in videos if len(v['duration'].split(':')) < 3]
print('60분 이하 영상 수:', len(videos))
# Out:
# 총 영상 수: 4
# 60분 이하 영상 수: 4

# %% [markdown]
# # 자막 내용 요약하기

# %% [markdown]
# ## API KEY를 위해 env 불러오기

# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

model = ChatOpenAI(model="gpt-4o-mini")
model.invoke('안녕?') # 언어 모델이 잘 설정되었는지 테스트
# Out:
# AIMessage(content='안녕하세요! 어떻게 도와드릴까요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 10, 'total_tokens': 20, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-Cd5igYGNRoKzjhtwfhCWpfg3Ss2iB', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--ddc0a638-0b3c-4284-89fe-c7c5c88c5805-0', usage_metadata={'input_tokens': 10, 'output_tokens': 10, 'total_tokens': 20, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ## 영상 1개 요약

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_classic.chains.combine_documents import create_stuff_documents_chain

# 동영상 요약 프롬프트 작성
prompt = ChatPromptTemplate.from_messages(
    [("system", "다음 영상에 대한 요약을 한국어로 만들어줘 :\\n\\n{context}")]
)

chain = create_stuff_documents_chain(model, prompt)

result = chain.invoke({"context": videos[0]['content']})
result
# Out:
# '이 영상에서는 미국 선거 제도의 독특한 점과 선거인단 시스템에 대해 설명하고 있습니다. 미국에서 유권자가 직접 투표하는 것이 아닌, 선거인단이라는 중간자를 통해 후보가 선출된다는 점이 주요 차별점입니다. 선거인단은 각 주별로 배분되며, 예를 들어 조 바이든 후보가 캘리포니아주에서 더 많은 표를 얻으면 그 주의 모든 선거인단을 가져가게 됩니다. \n\n영상에서 설명하는 바에 따르면, 후보가 얻은 선거인단이 270명을 초과해야 승리하는 구조입니다. 또한, 배신 투표와 같은 선거인단의 자율성에 대해서도 언급되며, 일부 주에서는 배신 시 벌금을 매기거나 해당 선거인단에서 제외될 수 있습니다. \n\n또한, 선거를 통해 승패를 좌우할 수 있는 주들에 대한 전략적 접근의 중요성도 강조되며, 이전 선거에서의 교훈을 바탕으로 후보들이 집중해야 할 지역이 어떻게 변화했는지를 설명합니다. 마지막으로, 우편 투표의 용이성과 그것이 정당에 미치는 영향에 대한 논의로 마무리됩니다.'

# %% [markdown]
# ## 모든 비디오에 대해 요약 생성

# %%
from tqdm import tqdm # tqdm은 진행 상황을 보여주는 라이브러리

for v in tqdm(videos):
    v['summary'] = chain.invoke({"context": v['content']})
   
videos
# Out:
# 100%|██████████| 4/4 [00:27<00:00,  6.85s/it]
# [{'id': '4A3P9Tgm8wc',
#   'thumbnails': ['https://i.ytimg.com/vi/4A3P9Tgm8wc/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLBiKa6FlGtJbPpVcHb4Nkfj_G7yqQ',
#    'https://i.ytimg.com/vi/4A3P9Tgm8wc/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLA9dp_amuxkebdEB0E_Yg87rC4ZQA'],
#   'title': '[2020 미국 대선] 표 적게 받고도 대통령 된다? 복잡한 선거제도 6분 총정리 ❙ Won Less, but Elected Anyways? / 비디오머그',
#   'long_desc': None,
#   'channel': '비디오머그 - VIDEOMUG',
#   'duration': '5:50',
#   'views': '조회수 518,254회',
#   'publish_time': '5년 전',
#   'url_suffix': '/watch?v=4A3P9Tgm8wc&pp=ygUN66-46rWtIOuMgOyEoA%3D%3D',
#   'video_url': 'https://youtube.com/watch?v=4A3P9Tgm8wc&pp=ygUN66-46rWtIOuMgOyEoA%3D%3D',
#   'content': [Document(metadata={'source': '4A3P9Tgm8wc'}, page_content='[박수] 하지만 전체 득표수에 트럼프보다 20만 표 이상 더 얻은 것으로 드러나 독특한 미국 선거제도의 희생이 됐다는 트럼프보다 20만 표 이상 더 얻은 것으로 드러나 [음악] 그 미국 선거가 다른 나라와 가장 큰 차이를 가지는게 바로 선거인단이 건데요 유권자와 후보 사이에 그 중간자가 하나 존재한다고 생각하시면 될 거 같아요이 538명의 선거인단을 50개 주와 워싱턴 DC 여기에다가 이제 배분을 하는데 그래서 예를 들어서 캘리포니아주 같은 경우에 조바이든 후보와 트럼프 후보를 사람들이 이제 찍어요 그런데 집계를 해보니까 조바이든 후보가 천 한표 그다음에 트럼프 대통령이 표를 받았어요 그러면 캘리포니아 주는 인구가 굉장히 많아서 신 다섯명을 가져가거나 명을 한 표를 더 받은 조바이든 후보가 다 가져가는 거죠 그거를 전국 차원에서 집계를 해서 538명의 과반은 270명이아요 270명의 선거인 들 먼저 획득한 후보가 선거에서 이기게 되는 [음악] 거죠 물론 개인적인 입장에서 보면 내 표가 사표가 됐지만 미국 전역에서 보면 민주당이 우세인 지역도 있고 공화당이 우세인 지역도 있으니까 서로 사표가 돈이 된다고 해야 될까요 사실 미국 의회에 선거인단 제도를 없애자라고 법안이 몇백개가 지금까지 발휘가 되긴 했어요 하지만 단 한 번도 의회를 통과하지 못했는데 미국에 굉장히 오랫동안 존재했던이 제대로 없애면 어 우리당에 불리한 거 아니야 이런 근본적인 두려움이 있어서 사실 개혁이 안 이루어지고 있었거든요 굳이 선거인단 입장에서 그 후보한테 투표할 의무는 없는 거 아닌가요 그냥 속된말로 배신을 할 수 있는 건 아닌지네 맞습니다 사실 의문은 없어요 그래서 실제로 배신 투표가 가끔 일어나긴 해요음 미국의 이제 32개 주와 워싱턴 DC 같은 경우는 배신 투표를 했을 때 벌금을 매긴다 그나이 사람을 바로 선거인단에 빼 버린다거나 이런 식으로 할 수 있고요 반면에 이제 18개 주는 아무런 그 처벌 조항이 없어요 배신을 했다라는 거를 사람들이 다 알 수 있는 거예요네 왜냐면 선거인단 투표는 간식이든 [음악] 그래서 11월 3일에 이제 올해 투표를 하잖아요 각 주별로 이제 누가 한 표라도 더 받았는지 이제 집계를 하죠 그러면 선거인단이 이제 12월 14일에 각 주의 주도로 갑니다 거기에서 각각 후보 이름을 써내는 거예요 선거인단이 또 투표를 한 거를 공개하는 거는 내년 2021년 1월 6일 날 의회에서 하게 되는 거예요 그 과정까지가 사실 마무리가 되야 미국 대통령이 공식으로 이제 선출이 되는 죠 가끔 한국에서 미국 선거는 간접 선거라는 설명을 제가 볼 때가 있는데 미국은 직접 [음악] 선거예측 네 그다음에 오하이오 바로 옆에 있는 오하이오 르브론 제임스의 고향이죠 그다음에 미시건 GM 같은 미국의 자동차 산업이 많은 곳 그다음에 위스콘신 여기는 이제 뭐 밀워키 아든 이런 도시가 있고 그다음에 옥수수밭이 엄청 많은 아이와 그리고 마지막으로 이제 플로리다 여기 요렇게 지금 제가 스티커를 붙인 여섯 개 주가 왜 중요하냐면 2012년까지는요 스티커가 있는 주들이 파란색이 2016년에 빨간색으로 바뀐 거예요이 주들의 특징이 뭐냐면 저희가 지난번에 얘기했던 백인 블루 컬러 노동자들이 굉장히 많은 주들이 지난 2016년 선거에서 미국에서 한 1억 2천만 명 정도가 투표를 했거든요 근데 그 중에서 펜실베니아 미시건 위스콘신에 사는 10만 명의 표가 그 지난번 선거를 결정했다고 보시면 돼요 힐러리 클린턴 같은 경우에 선거가 끝난 다음에 많은 비판을 받은게 실 뉴욕이나 캘리포니아에서 펀드레이징 행사를 덜 하고 미시간이나 위스콘신에 가서 적극적으로 유권자들을 만났어야 하는데 캠프 내에서 미시간을 이제 경합주로 보지 않았기 때문에 전략에 이제 실패라고도 볼 수 있는 거죠 그래서 지금 조바이든 후보 보시면 정말 열심히 미시건 위스컨신 펜실베니아 가고 있거든요 2016년에 이제 패배를 교훈 삼아서 이번에 전략을 짠 거죠 우편 투표가 쉬울까요 투표소에 가서 투표를 하는게 쉬울까요 투자가 쉽겠죠 아 그럴까요 우편 투표를 하면 민주당의 유리한가 공화당의 유리한가 결론은 [음악]')],
#   'summary': "이 영상에서는 미국의 선거 제도, 특히 선거인단 제도에 대해 설명하고 있습니다. 미국은 유권자와 후보자 사이에 선거인단이라는 중간자가 존재하는 독특한 시스템을 가지고 있으며, 이 선거인단의 수는 총 538명으로 각 주와 워싱턴 DC에 배분됩니다. 주별로 가장 많은 표를 얻은 후보가 해당 주의 모든 선거인단을 차지하는 방식입니다. 예를 들어, 조 바이든 후보가 캘리포니아주에서 더 많은 표를 얻으면 그 주의 선거인단을 모두 가져갑니다.\n\n영상에서는 선거인단 제도를 없애자는 법안이 여러 차례 발의되었으나 정치적 두려움으로 인해 통과되지 않았음을 언급합니다. 또한, 선거인단이 자신의 소속당과 다른 후보에게 투표하는 '배신 투표'가 가끔 발생하며, 일부 주에서는 벌금을 부과하거나 선거인단에서 제명할 수 있다고 설명합니다.\n\n특히 2016년 선거에서 백인 블루 컬러 노동자가 많은 주들이 선거 결과에 중요한 영향을 미쳤다는 점을 강조하며, 조 바이든 후보가 이번 선거에서 전략적으로 미시간, 위스콘신, 펜실베니아를 중점적으로 방문하고 있다는 내용을 전달합니다. 마지막으로, 우편 투표의 용이성과 그것이 민주당과 공화당에 미치는 영향을 논의합니다."},
#  {'id': 'yUrKS8KldPk',
#   'thumbnails': ['https://i.ytimg.com/vi/yUrKS8KldPk/hqdefault.jpg?sqp=-oaymwEjCOADEI4CSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLCXV5GBAOBgjsk55XCwjUmlZCl-gw'],
#   'title': '[Explained] 미국 대선, 어렵지 않아요!  / SBS',
#   'long_desc': None,
#   'channel': 'SBS 뉴스',
#   'duration': '5:12',
#   'views': '조회수 142,848회',
#   'publish_time': '9년 전',
#   'url_suffix': '/watch?v=yUrKS8KldPk&pp=ygUN66-46rWtIOuMgOyEoNIHCQkICgGHKiGM7w%3D%3D',
#   'video_url': 'https://youtube.com/watch?v=yUrKS8KldPk&pp=ygUN66-46rWtIOuMgOyEoNIHCQkICgGHKiGM7w%3D%3D',
#   'content': [Document(metadata={'source': 'yUrKS8KldPk'}, page_content='힐러리와 트럼프 샌더스 요즘 국내 언론에도 자주 등장하는 이름들이죠. 2016년 미국은 지금 대통령 선거전이 한창입니다. 선거 당일 국민들이 직접 투표해서 대통령을 뽑는 직접 선거 방식인 우리나라와는 달리 미국 대선은 국민과 대통령 사이에 각 주위에서 선발된 선거인단이 깨어 있습니다. 국민은 선거 인단을 직접 뽑고 선거인단이 다시 대통령을 뽑는 간접 선거 방식입니다. 게다가 코우커스니, 프라이머리니 또 슈퍼 화이리니 하면서 생소한 용어가 나오다 보니 미국 대선을 두고 복잡하다, 잘 모르겠다 이렇게 생각하시는 분들 많으실 겁니다. 그래서 미국 대선 과정을 알기 쉽게 정리해 봤습니다. 미 대선은 크게 보면 각 당에서 대통령 후보를 선출하는 경선 과정 그리고 본선일 할 수 있는 대통령 선거 과정으로 구분할 수 있습니다. 먼저 경선 과정부터 살펴보면 대원 선거와 대통령 후보 선출로 구성되 있습니다. 대의원을 먼저 뽑고 뽑힌 대원들이 전당 대회장에 모여 대통령 후보를 선출하는 거죠. 각 당의 경선 주자들은 각 줄을 돌면서 유권자들의 지지를 호소하는데 엄밀히 말하면 유권자들이 특정 후보를 뽑는게 아니라 특정 후보를 지지하는 대의원을 뽑는 겁니다. 대의원 선거는 복잡하게도 다시 두 가지 방식으로 나뉘는데 바로 코커스와 프라이머입니다. 코커스는 당원 대회 정당 집회로 당원들만 참석하는 반면 프라이머리는 당원이 아닌 일반 시민도 참여하는 대의원 선출 방식입니다. 여러 주 가운데 아이오와 코커스와 뉴 햄프쇼 프라이머리가 가장 유명한데요. 대통령 후보를 뽑는 경선의 출발점이자이 두 곳의 선거 결과가 도미너처럼 이어지는 바른 주 선거에도 영향을 끼치기 때문입니다. 아이오와 포커스와 뉴햄프쇼 프라이머리의 시작 다음에 바로 경선의 뿌트로 불리는 슈퍼 화요일이 이어집니다. 12개주에서 동시에 프라이머리가 실시되는 3월 두째 주 화요일입니다. 이날 법인 데이원수가 당의 후보를 선출하는데 필요한 베이원의 과반수를 넘어서거나 근접할 정도로 많아서 슈퍼 화요일이란 명이 붙었죠. A원들은 뽑히기 전부터 누구를 지지하는지 공개적으로 밝히기 때문에 경선주자들이 각 줄을 돌며 확보한 대의원수를 집게하면 누가 최종 후보로 결정될지 윤곽이 드러나게 말입니다. 전체 대의원수의 과반을 얻은 경선 주자가 당해 대통령 후보가 됩니다. 이렇게 선출된 대의원들이 모여 전당 대회를 열고 당해 대통령 후보를 공식적으로 선출하는데 어느 후보가 대의원의 과반을 확보했는지 이미 알고 있는 상황이라 전당 대회는 사실 후보를 지명하는 축제장이라고 볼 수 있습니다. 이렇게 당해 후보를 뽑는만 반년 정도 걸립니다. 대선 곤선은 아직 시작도 안 했는데 말했죠. 그럼 이제 각당 후보가 결정된 이후에 본선을 알아볼까요? 본선은 선거인단 선거와 대통령 선거로 구성되 있습니다. 각당 후보는 역시 전국 각주를 돌며 지지를 호소하게 됩니다. 유권자들은 지지하는 후보에게 한표를 행사하게 되는데 한 표라도 더 받은 후보가 그주에 배정된 선거인단을 모두 가져가게 됩니다. 승자 독시 구조입니다. 선거인단수는 각주의 인구수에 비례해 배정되는데 인구가 가장 많은 캘리포디아주는 쉬운 다섯 명이 알레스카 같은 곳은 세 명에 불과합니다. 그러니까 후보로선 선거인단이 큰 지역에서이기는게 중요하겠죠. 다만 메인주와 네브라스카주는 투표율대로 선거인단을 나눠갔습니다. 선거인단 총수가 538명으로 과반수인 270명의 선거인단을 확보하면 대통령에 당선됩니다. 오바마 롬니가 맛붙었던 지난 대선에선 오바마 대통령이 332명의 선거인단을 확보해 재선에 성공했습니다.이 이 특이한 승자 독시 구조 때문에 미국의 대선에서는 국민의표를 더 바꿔도 대통령이 되지 못하는 아이러니한 일이 벌어지기도 하는데요. 실제로 지난 2000년 대선에선 보호민주당 후보가 도시 공화당 후보다 유권자로부터 54만 정도를 더 받았지만 대통령이 되지 못했습니다. 유권자 총표수는 적었지만 도시 후보가 승자 독식을 통해 선거인단수를 더 많이 확보해이긴 겁니다. 선거인단 선출이 끝나면이 선거인단이 다음 달엔 12월 대선 투표를 합니다. 결과에 이미 나왔지만 말입니다. 자, 1년 동안 펼쳐지는 다섯 복잡한 미국의 대선 과정이 좀 이해되셨나요? 국제정치와 경제, 군사적 측면 등 거의 전 방면에 걸쳐 초광대국인 미국의 위상으로 볼 때 미국의 대통령이 누가 되느냐는 지구촌의 관심사이기도 합니다. 오바마 대통령에 이어 미국의 제46대 대통령은 누가 될지 전 세계가 지켜보고 습니다.')],
#   'summary': "이 영상은 2016년 미국 대통령 선거에 대한 과정과 구조를 설명하고 있습니다. 미국 대선은 간접 선거 방식으로, 유권자들이 선거인단을 뽑고 이 선거인단이 최종적으로 대통령을 선출합니다. 대선 과정은 크게 경선과 본선으로 나눌 수 있습니다.\n\n경선 과정에서는 각 당에서 대의원을 선출하고, 이 대의원들이 전당대회에서 대통령 후보를 정합니다. 대의원 선출 방식은 코커스와 프라이머리 두 가지로 나뉘며, 각각 당원들만 모인 회의와 일반 시민도 참여하는 투표방식입니다. 아이오와 코커스와 뉴햄프셔 프라이머리는 경선의 중요한 출발점입니다. 이후 슈퍼 화요일에 여러 주에서 동시에 프라이머리가 진행되어 결정적인 영향을 미칩니다.\n\n본선에서는 각 당 후보가 전국을 돌아다니며 지지를 호소하고, 유권자들은 지지하는 후보에게 투표합니다. 여기서 승자는 해당 주의 모든 선거인단을 가져가는 '승자 독식' 구조로 되어 있습니다. 각 주의 선거인단 수는 인구에 비례하며, 총 538명의 선거인단 중 과반인 270명을 확보한 후보가 대통령으로 결정됩니다. 이 때문에 일부 후보는 유권자 수에서는 더 많은 표를 받아도 대통령이 되지 못하는 아이러니한 상황이 발생하기도 합니다.\n\n영상은 미국 대선의 복잡한 과정을 알기 쉽게 정리하고 있으며, 미국의 대통령이 누가 될지에 대한 글로벌한 관심을 강조하고 있습니다."},
#  {'id': 'GGPiVs7GC-M',
#   'thumbnails': ['https://i.ytimg.com/vi/GGPiVs7GC-M/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLC-pM-eV4g21mUoXBO9auwPSIKThg',
#    'https://i.ytimg.com/vi/GGPiVs7GC-M/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLCB4e7S4R4Rz3R2QIuCQrZ2EUpp7A'],
#   'title': '[데이터M] 2024 미국 대선 개표 상황 (2024.11.06/뉴스특보/MBC)',
#   'long_desc': None,
#   'channel': 'MBCNEWS',
#   'duration': '2:57',
#   'views': '조회수 19,459회',
#   'publish_time': '1년 전',
#   'url_suffix': '/watch?v=GGPiVs7GC-M&pp=ygUN66-46rWtIOuMgOyEoA%3D%3D',
#   'video_url': 'https://youtube.com/watch?v=GGPiVs7GC-M&pp=ygUN66-46rWtIOuMgOyEoA%3D%3D',
#   'content': [Document(metadata={'source': 'GGPiVs7GC-M'}, page_content='네 여기는 다시 데이터입니다 현재 알라스카를 제외하고 대부분의 지역 개표 중입니다 자 그런데 아직 결정이 안 된 지역들 옅은 파란과 옅은 빨강으로 채워진 지역들 대부분 경합주 있데요 지금 보시면 이쪽 위쪽 세 곳의 옅은 핑크 색들 이곳들 러스트 벨트고리 이곳 두 곳 노스캐롤 아 네바다와 에리조나 같은 경우도 경합주 있습니다이 경합주 남은 곳들 다 빨갛게 물들어 있고요 노스 캐롤라이나와 조지아 같은 경우는 이미 트럼프가 앞 것으로 예측이 되어 있는 상황입니다 경합주 일곱 것에서 모두 트럼프가 앞서고 있는 상황인데요 한 곳 한 곳 대표 상황 자세하게 확인 해 보도록 하겠습니다 먼저 펜실베니아가 보겠습니다 펜실베니아 현재 트럼프 51.1% 해리스 47.8% 트럼프가 3% 포인트 이상 앞서고 있는 상황입니다 개표 92% 진행이 됐는데요 두 후보자의 차이 2% 포인트에서 4% 포인트 차이가 왔다 갔다 거리면서 좁혀졌다 넓혀졌다 하고 있는 상황입니다 현재에 지금 노스 캐롤라이나와 조지아를 트럼프가 가져갈 것으로 거의 확 확실시되면서 펜실베니아 해리스가 확보하지 못하면 트럼프가 47대 미국 대통령이 되는 상황인데요 그렇기 때문에 끝까지이 지역 지켜보셔야겠습니다 다음 지역으로 가보겠습니다 이번 지역은 미 시간입니다 자 미 시간에서도 트럼프가 52.1% 해리스가 46.1% 트럼프가 크게 앞서고 있는 상황입니다 자 미시간은 해리스에게 가장 유리한 지역 유리한 경합주 중에 하나로 꼽혔는데 지금 현재 상황으로 봐 가서 트럼프가 6% 포인트 앞서고 있는 것으로 보입니다 자 다음 지역도 보겠습니다 이번에도 러스트 벨트인데 위스컨신 가봅니다 자 위스콘 신도 트럼프 51.2% 해리스 47.2% 트럼프가 4% 포인트 앞서고 있는 상황입니다 자 미시간과 위스콘신 아직 개표가 100% 이루어진 건 아니지만요 현재 상황으로 봤을 때 콜리지 타운이라고 하는 곳들에서 해리스가 성적이 좋지 않다고 합니다이 콜리지 타운은 대학이 위치한 곳인데 젊은 사람들이 많이 살아서 이곳에서 크게 앞서야 해리스가 앞설 수 있다고 하는데요 2020년 바이든의 성적과 비교했을 때 해리스가 좀 많이 처진다 처지는 상황이라고 합니다 그렇기 때문에 위스콘신과 미시간 차이가 점점 벌어질 수 있는 상황이라는 점 유념하셔야습니다 다음 지역도 보시겠습니다 이번에는 남부로 내려가 봅니다 애리조나 리 애리조나 같은 경우는 트럼프는 49.9% 해리스는 49.2% 0.7% 포인트 차이 나고 있습니다 이곳 개표 52% 진행이 됐는데요 당초에 해리스가 조금더 유리할 것으로 생각됐던 러스트 벨트보다 선벨트인 애리조나에서 차이가 조금 더 적은 것 볼 수 있습니다 자 애리조나 같은 경우는 캘리포니아와 맞 맞다 있어서 캘리포니아 민주 당세가 강한 캘리포니아 사람들이 많이 이주를 한 것으로 알려졌는데요 그 영향이 조금 있었을지 끝까지 지켜보겠습니다 마지막으로 내바다 하나 더 볼까요 네바다는 준비가 안 된 거 같습니다 내바다 개표 상황 들어오는 대로 확인해 보겠습니다 지금까지 데이터 m이었습니다')],
#   'summary': '현재 알라스카를 제외한 대부분의 지역에서 개표가 진행 중이며, 일부 지역은 경합주로 분류되고 있습니다. 현재 트럼프가 대부분의 경합주에서 앞서고 있으며, 특히 펜실베니아에서 51.1%의 지지를 받고 있는 반면 해리스는 47.8%로 뒤처져 있습니다. 펜실베니아의 개표가 92% 진행된 상황에서 두 후보 간의 차이는 2%에서 4% 사이에서 변동하고 있습니다.\n\n노스 캐롤라이나와 조지아에서도 트럼프가 우세한 상황이며, 트럼프가 펜실베니아에서 해리스를 이기지 못하면 당선이 불가능할 것으로 보입니다. 미시간에서는 트럼프가 52.1%로 해리스를 46.1%로 앞서 있는 상황이고, 위스콘신에서도 비슷한 양상으로 트럼프가 51.2%를 기록하고 있습니다. \n\n애리조나는 트럼프가 49.9%로 해리스를 49.2%로 조금 앞서고 있으며, 개표가 52% 진행된 상황입니다. 해리스가 강세를 보일 것이라 예상했던 지역들이지만, 현재 트럼프가 앞서 있는 일들이 확인되고 있습니다. 전체적으로 경합주에서의 추세가 확인되고 있는 중입니다.'},
#  {'id': 'LKHzlzh7HBs',
#   'thumbnails': ['https://i.ytimg.com/vi/LKHzlzh7HBs/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLDeGBYbq18px6ES3r95qgC-rERrMg',
#    'https://i.ytimg.com/vi/LKHzlzh7HBs/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLB4q1lp3LRY4-ASZp-U0YU5Dqq9dw'],
#   'title': "🇺🇸[미국대선특집] 대통령 선거 제도 '선거인단'의 유래와 역사",
#   'long_desc': None,
#   'channel': '조승연의 탐구생활',
#   'duration': '15:33',
#   'views': '조회수 1,257,972회',
#   'publish_time': '5년 전',
#   'url_suffix': '/watch?v=LKHzlzh7HBs&pp=ygUN66-46rWtIOuMgOyEoA%3D%3D',
#   'video_url': 'https://youtube.com/watch?v=LKHzlzh7HBs&pp=ygUN66-46rWtIOuMgOyEoA%3D%3D',
#   'content': [Document(metadata={'source': 'LKHzlzh7HBs'}, page_content='안녕하세요 조승연 입니다 이제 11월 3일이 미국 대선이 줘 그러다 보니까 이제 많은 분들이 미국의 선거제도 에 대한 영상을 요청을 해 주셨어요 그래서 오늘은 미국의 굉장히 독특한 대통령선거 시스템인 선거인단 제도에 대한 영상을 한번 만들어봤습니다 이 미국대선 때가 되면은 이 대선 결과를 지켜보는 우리같은 외국인들은 물론이고 미국인들도 큰 혼란에 빠질 때가 많습니다 그 성제 미국의 대통령 선거 저도 이 선거인단 제도가 굉장히 복잡하기 때문이죠 이 선거인단 제도가 있기 때문에 대다수의 국민들의 표를 받은 사람이 대통령이 되지 못하는 경우가 미국 역사에서 5번 있었습니다 최근에 알고 와 힐러리 클린턴이 이런 방식으로 대통령 선거에서 떨어지게 되면서 사람들이 또 한번 선거인단 제도가 정확하게 뭐냐 이런 제도를 오해 가지고 있냐 미국이 이런거에 대해서 관심을 가지게 된거죠 미국의 독특한 정치 시스템을 이해하기 위해선 일단 미국에 이름을 보면 됩니다 2 우리가 미국을 이후 했어 유나 리 스 데이 쳐보면 할까 이렇게 불렀는데 리 제이윤 아리스 데이터 범해 할까라고 앞에 빚이라는 복수형 수식어를 사용을 하거든요 마치 나라가 하나가 아니라 여러 개가 있는 것처럼 얘기를 한다는 거죠 이 나라 이름이 왜 이런 식인 g 를 이해하기 위해서는 우리가 미국이 어떤 상황에서 건국일 했는지 그 건국 초기 로 돌아갈 필요가 있구요 그 건국 초기 스토리를 통해서 미국의 선거인단 제도를 이해할 수가 있는 거죠 일단 이 미국의 민주주의를 같다 이해하는 데 굉장히 도움이 되는 그 분석을 한 사람이 있습니다 알렉스 d 2b 일 이라고 하는 프랑스 외교관 이고요 미국의 민주주의라고 하는 미국 민주주의 의 역사에 관련된 책을 있었죠 프랑스의 민주주의와 미국의 민주주의 를 비교하는 내용이 있는데 그 내용이 미국을 이해하는 데 굉장히 큰 도움이 된다고 저는 생각을 해요 프랑스의 민주주의 같은 경우에는 이미 왕정이 공부하고 국가의 기틀이 만들어져 있는 나라에서 일어났기 때문에 그 왕이 가지고 있는 권한을 국민들이 다수결로 결정을 하는 방식으로 같다 그래서 결국 이 국가의 권력이 정부의 집중돼 있는 거에 대해서 사람들이 그 다 큰 불만을 제기하지 않고 그 정부의 결정권 자들을 내손으로 고를 수 있다는 것에 만족한다 이렇게 얘기합니다 미국 같은 경우에는 남의 간섭을 받기 가 얼마나 싫었는지 목숨을 걸고 배를 타고 대서양을 건너서 자 기대될 나름대로 공동체를 만들고 스스로 규율을 만들고 자유롭게 살아가던 여러 동네 들이 있는 그런 상황에서 출발을 했다는 거죠 그러다가 이제 동네가 따로따로 할 수 없는 큰 공동 프로젝트가 생기게 되면 자기네들 나름대로 주권을 가지고 있는 작은 공동체들이 중앙정부 라는 걸 만들어서 권력을 조금 때 지게 된다 라는 겁니다 즉 프랑스의 민주주의는 위해서 권력을 떼서 아래로 뿌리는 것이라면 미국의 민주주의는 아래에서 권력을 떼서 위로 살짝 모으는 형태로 진화를 했기 때문에 그 민주주의가 단어는 같을지 몰라도 본질적으로 형태와 정신이 같을 수 없다 라고 분석을 했어요 미국이 영국을 쫓아내고 독립을 이룬 다음에 이 13개 s 데이 스테이트 가 오늘 나는 주 라는 뜻으로 쓰이지만 원래는 국가라는 단어 잖아요 13개의 주권을 가진 스 데이트의 대표들이 힐라 될 거야 에 모여서 더 큰 공동체를 만들기 위해서 정관을 쓰는 작업을 하게 됩니다 이것이 바로 커스티 숀 컨벤션 이고 거기서 수많은 다른 이권과 다른 목표를 가지고 있는 여러 스테이 뜰이 동의를 할 수 있는 여러 협상을 통해서 만들어진 더 q 먼트 가 바로 오늘날 우리가 알고 있는 미국의 헌법 인 거예요 그런데 비슷한 시기에 만들어진 초기 민주 헌법 프랑스의 헌법과 미국 헌법을 비교해보면 느낌 자체가 굉장히 다릅니다 프랑스의 헌법은 이미 체계가 갖춰져 있는 국가의 원한을 왜 민중 한테 나누어 줘야 되는지 그리고 어떤 형태로 나눠줘야 되는지를 갔다가 정리한 이상적인 도큐먼트 라면 미국은 13개의 서로 다른 목표가 다르니 권을 가지고 있는 주에 수많은 이렇게 타협을 통해서 만들어진 일종의 비즈니스 도큐먼트 같은 느낌을 주거든요 이런 타협 협상 의 과정을 굉장히 자세히 묘사한 책이 있는데 그 책의 제목이 업 브릴리언스 솔루션 천재적인 솔루션 이에요 18세기 는 우리가 이제 계몽주의 시대 라고 하고 계몽주의 시대의 브루조아 개청 들 이 미국의 헌법을 제정한 사람들 우리가 흔히 파운딩 카드에서 건국 아버지라고 부르는 사람들의 교육은 그리스 로마 의 역사가 굉장히 중요한 부분을 차지하고 있었습니다 특히 이제 미국이 영국에서 독립을 한 다음에 왕이 없는 나라를 만들려고 하는데 그 당시 초기 미국인들이 알고 있는 모든 다른 나라들 지금 유럽의 군주 국가들은 전부다 왕이 있었습니다 그러면은 이 공화정이 라고 하는 생각이 어디서 나왔냐 라고 하면은 사실 수천년 전에 멸망한 나라들 즉 아테네와 로마의 황금비의 대한 이상에서 나왔어요 고대 아테네와 로마 초기에 정치 형태가 의회 가 가장 강력한 힘을 가지고 있는 공화정의 형태를 띠고 있었기 때문에 커스티 셜 컴퓨터 4 모여있는 건국 아버지 들도 미국이라는 나라를 만든다면 은 의회 가 가장 강력한 힘을 가지고 있는 공화정의 형태를 떼어야 된다 라는 것에서 는 대체로 동의를 하고 있었어요 또 18세기의 신사 부르주아 계층들이 대체로 동의하는 두번째 내용이 있는데 그거는 좀 여러분이 놀라고 할 수도 있습니다 바로 민주주의 의 데모 클래스 라는 단어를 나쁜 단어 라고 생각했다는 겁니다 그리스 로마의 문헌에 나온 민주주의 란 단어는 지금과 dis 가 굉장히 달랐어요 고대 아테네와 로마의 공화정 은 절차에 의한 정치 얻습니다 이 절차는 권력을 분산시키는 것이 그 목적 이었죠 한 사람이 자기 맘대로 뭔가를 할 수 없었다는 겁니다 근데 가끔씩 대만 로그 라고 그리스도 로 불리는 사람들이 나타납니다 민중 선동가 란 뜻이죠 이들은 이 절차를 무시하고 일반 평민들의 과반수의 지지를 받게 되면서 민중의 힘을 이용해 가지고 중간에 있는 개청 들을 다 묵살해 버리는 그런 정치를 하는 경우가 있었어요 대표적인 예가 이제 고대 로마의 율리우스 카이사르 하는 사람이죠 고마 정을 종말 시켜버린 이 사람이 스스로에게 주었던 타이틀이 있죠 b 테이터 라는 타이틀이 오늘날 독재자로 쓰일 정도로 그 당시 사람들한테는 가장 피해야 될 모델 중의 한 명이었습니다 민주주의에 대해서 이 건국 아버지들이 어떤 생각을 가지고 있는지 이제 직접 인용문을 갔다가 찾아 봤거든요 뉴욕 대표로서 헌법에 굉장히 중요한 역할을 한 알렉산더를 헤밀턴 은 뭐라고 했냐면 요 만약에 우리가 너무 민주주의 쪽으로 치우치게 된다면 우리는 왕정이 나 또 다른 형태 독재로 뻗어 나갈 수밖에 없다 이렇게 얘기했습니다 그게 이제 고대 그리스와 로마 역사에서 얻은 이들의 교훈 이에요 또 토마스 제퍼슨이 사람은 민주주의라는 것은 51% 의 사람이 나머지 49% 의 사람의 권리를 빼앗아 할 수 있는 제도를 말합니다 이렇게 얘기했습니다 제임스 메디슨 이 사람들이 버지니아 출신이죠 민주 국가들은 대체로 그 삶이 짧았고 나라가 금방 망했다는 겁니다 그 생이 짧았고 그 죽음은 폭력적이 어따 3 2 정체에 의한 내전이 있었던 그런 상황을 얘기를 하는 거죠 매사추세츠 대표 던져 안에 람 쓰는 뭐라 그랬냐 민주국가와 중에서 자살을 하자 는 민주국가 넓다 이것도 이제 아테네와 그 로마가 결국 독재가 되었다 라는 얘기를 하고 있는 겁니다 이렇기 때문에 이제 국가원수를 일반 민중 과반수 의 지지를 받는 사람으로 한다라는 것은 사실 건국 아버지 들의 사상의 근본적으로 어긋나는 거겠죠 그렇기 때문에 이제 초기에는 대통령이란 자리를 아예 만들지 말자 왜냐면은 로마시대 나 아테네 역사를 보면 은 의회에서 집정관이 나 호민관 같은걸 임명 하게 되면 직접 많이 나 호민관 2 하필 이즘 정치를 하게 되고 동화적인 운 어지는 경우가 워낙 많았기 때문에 아예 대통령 난 자리를 만들지 말자 라는 얘기도 있었어요 하지만 그 당시 다른 유럽 국가들이 모두 다 왕정 이었기 ...
#   'summary': '이 영상에서는 미국 대선의 독특한 선거인단 제도에 대해 설명하고 있습니다. 조승연은 이 시스템이 복잡하고 많은 혼란을 초래하는 이유를 설명하며, 미국의 정부 구조와 민주주의의 특성을 이해하기 위해서는 역사적 배경을 알아야 한다고 강조합니다.\n\n미국은 독립 초기 13개 주가 모여 형성된 연합국가로, 선거인단 제도는 각 주의 권력을 각각 고려하면서도 중앙 정부를 효율적으로 운영하기 위해 만들어졌습니다. 선거인단 제도는 각 주의 인구에 따라 선거인단 수가 결정되며, 주 전체의 투표 결과로 인해 선거인단이 특정 후보를 지지하게 됩니다.\n\n조승연은 미국과 프랑스의 민주주의 비교를 통해 미국 민주주의의 독특한 진화 과정을 설명하고, 헌법 제정 과정에서의 타협과 협상의 중요성을 강조합니다. 그는 또한 선거인단 제도가 어떻게 형성되었는지, 그리고 초기 건국 아버지들이 의도했던 이상적인 시스템이 어떻게 왜곡되었는지를 설명합니다.\n\n영상은 결국 선거인단 제도가 미국의 헌법과 깊이 연관되어 있으며, 미국의 정체성을 구성하는 중요한 요소라고 결론짓습니다. 조승연은 앞으로도 이 제도가 유지될 것이라고 예상하며, 현재의 정치 상황에 대한 우려를 표합니다.'}]
